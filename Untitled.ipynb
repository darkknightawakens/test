# %%
ls
# Out:
# aws/  save.py  Untitled.ipynb  work/

# %%
ls
# Out:
# aws/  __pycache__/  save.py  Untitled.ipynb  work/

# %%
ls
# Out:
# aws/  __pycache__/  save.py  Untitled.ipynb  work/

# %%
ls
# Out:
# aws/  __pycache__/  save.py  Untitled.ipynb  work/
